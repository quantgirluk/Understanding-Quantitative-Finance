# %%
from fanchart.plot import *

parameters = load_boe_parameters()
history = load_boe_history()

probs = np.arange(0.05, 1, 0.05)
fan(pars=parameters, probs=probs)
# Out:
# Loading 2022Q3 parameters - as published by the BoE.
# Loading 2022Q3 historic CPI inflation data  - as published by the BoE.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <module>
#       4 history = load_boe_history()
#       6 probs = np.arange(0.05, 1, 0.05)
# ----> 7 fan(pars=parameters, probs=probs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/fanchart/plot.py:258, in fan(pars, probs, historic, color, title)
#     248 def fan(pars, probs, historic=None, color='xkcd:tomato red', title=None):
#     249     """
#     250     Returns a fanchart
#     251     :param pars: dataframe - Parameters table with columns Mode, Uncertainty, Skewness
#    (...)
#     256     :return: fanchart (figure)
#     257     """
# --> 258     return _fan_customised(pars, probs, historic=historic, color=color, grid=True, title=title, title_loc=None,
#     259                            darkmode=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/fanchart/plot.py:222, in _fan_customised(data, p, historic, color, grid, fig_size, title, title_loc, darkmode)
#     217     if i < results.shape[1] - 1:
#     218
#     219         # times =  pd.to_datetime(results.index.values)
#     220         # times = results.index.to_numpy()
#     221         times = results.index.to_pydatetime()
# --> 222         plt.fill_between(times, results.iloc[:, i], results.iloc[:, i + 1],
#     223                          alpha=alpha_fill[i], facecolor=color, edgecolor="none", linewidth=0.0)
#     225 if darkmode:
#     226     ax.axhline(y=2.0, color='white', linestyle='--', linewidth=1.5)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py:2526, in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2522 @_copy_docstring_and_deprecators(Axes.fill_between)
#    2523 def fill_between(
#    2524         x, y1, y2=0, where=None, interpolate=False, step=None, *,
#    2525         data=None, **kwargs):
# -> 2526     return gca().fill_between(
#    2527         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
#    2528         **({"data": data} if data is not None else {}), **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5367, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5365 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5366                  step=None, **kwargs):
# -> 5367     return self._fill_between_x_or_y(
#    5368         "x", x, y1, y2,
#    5369         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5272, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5268         kwargs["facecolor"] = \
#    5269             self._get_patches_for_fill.get_next_color()
#    5271 # Handle united data, such as dates
# -> 5272 ind, dep1, dep2 = map(
#    5273     ma.masked_invalid, self._process_unit_info(
#    5274         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5276 for name, array in [
#    5277         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278     if array.ndim > 1:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
